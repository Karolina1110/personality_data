# %%
import numpy as np
import pandas as pd
import utils
import seaborn as sn

# %% [markdown]
# # Load data

# %%
data_big = pd.read_csv('data/big_results.csv', index_col=0)
data_big
# Out:
#         EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  ...  \
# 0        4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0    1.0  ...
# 1        3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0    5.0  ...
# 2        2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0    5.0  ...
# 3        2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0    4.0  ...
# 4        3.0   3.0   3.0   3.0   5.0   3.0   3.0   5.0   3.0    4.0  ...
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...    ...  ...
# 499995   4.0   2.0   5.0   2.0   4.0   2.0   5.0   4.0   2.0    4.0  ...
# 499996   2.0   2.0   4.0   5.0   4.0   1.0   1.0   1.0   5.0    5.0  ...
# 499997   3.0   1.0   5.0   1.0   4.0   1.0   4.0   2.0   5.0    2.0  ...
# 499998   3.0   4.0   3.0   2.0   4.0   2.0   1.0   2.0   4.0    5.0  ...
# 499999   1.0   5.0   1.0   5.0   1.0   5.0   1.0   5.0   1.0    5.0  ...
#
#         _OPN9  _OPN10   EXT   EST   AGR   CSN   OPN  MAX_SCORE  TYPE      CORR
# ...

# %% [markdown]
# # Drop null and reset index

# %%
data_big=data_big.replace([np.inf, -np.inf], np.nan).dropna(axis=0)
# Drop rows with NaN
data_big=data_big.reset_index(drop=True)
data_big
# Out:
#         EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  ...  \
# 0        4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0    1.0  ...
# 1        3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0    5.0  ...
# 2        2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0    5.0  ...
# 3        2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0    4.0  ...
# 4        3.0   3.0   3.0   3.0   5.0   3.0   3.0   5.0   3.0    4.0  ...
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...    ...  ...
# 498050   4.0   2.0   5.0   2.0   4.0   2.0   5.0   4.0   2.0    4.0  ...
# 498051   2.0   2.0   4.0   5.0   4.0   1.0   1.0   1.0   5.0    5.0  ...
# 498052   3.0   1.0   5.0   1.0   4.0   1.0   4.0   2.0   5.0    2.0  ...
# 498053   3.0   4.0   3.0   2.0   4.0   2.0   1.0   2.0   4.0    5.0  ...
# 498054   1.0   5.0   1.0   5.0   1.0   5.0   1.0   5.0   1.0    5.0  ...
#
#         _OPN9  _OPN10   EXT   EST   AGR   CSN   OPN  MAX_SCORE  TYPE      CORR
# ...

# %% [markdown]
# # Filter data by best classes

# %%
best_class=data_big['TYPE'].value_counts()[:16].index.values.tolist()
best_class
# Out:
# [0, 1, 3, 4, 25, 7, 27, 14, 23, 20, 31, 5, 96, 179, 11, 16]

# %%
data_big_cleaned = data_big[data_big['TYPE'].isin(best_class)]
data_big_cleaned=data_big_cleaned.drop_duplicates()
data_big_cleaned=data_big_cleaned.reset_index(drop=True)
data_big_cleaned
# Out:
#         EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  ...  \
# 0        4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0    1.0  ...
# 1        3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0    5.0  ...
# 2        2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0    5.0  ...
# 3        2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0    4.0  ...
# 4        3.0   3.0   3.0   3.0   5.0   3.0   3.0   5.0   3.0    4.0  ...
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...    ...  ...
# 415057   3.0   1.0   4.0   3.0   2.0   1.0   3.0   4.0   4.0    4.0  ...
# 415058   4.0   2.0   5.0   2.0   4.0   2.0   5.0   4.0   2.0    4.0  ...
# 415059   2.0   2.0   4.0   5.0   4.0   1.0   1.0   1.0   5.0    5.0  ...
# 415060   3.0   1.0   5.0   1.0   4.0   1.0   4.0   2.0   5.0    2.0  ...
# 415061   3.0   4.0   3.0   2.0   4.0   2.0   1.0   2.0   4.0    5.0  ...
#
#         _OPN9  _OPN10   EXT   EST   AGR   CSN   OPN  MAX_SCORE  TYPE      CORR
# ...

# %%
data_big_cleaned['TYPE'].value_counts()
# Out:
# 0      143667
# 1      105328
# 3       30589
# 4       22700
# 25      14877
# 7       14634
# 27      14107
# 14      13665
# 23       9760
# 31       7874
# 20       7747
# 5        6874
# 96       6171
# 179      6066
# 11       5556
# 16       5447
# Name: TYPE, dtype: int64

# %% [markdown]
# # Add classes based on big 5 factors

# %% [markdown]
# extraversion - introversion E-I <br>
# emotional stability - neurotic S-N <br>
# agreeableness - antagonism A-T <br>
# conscientiousness - carelessness C-R <br>
# open - closed O-C

# %%
data_big_cleaned['B5_TYPE']=None
for index, row in data_big_cleaned.iterrows():
    t=''
    if row['EXT']>25:
        t+='E'
    else:
        t+='I'
    if row['EST']>25:
        t+='S'
    else:
        t+='N'
    if row['AGR']>25:
        t+='A'
    else:
        t+='T'
    if row['CSN']>25:
        t+='C'
    else:
        t+='R'
    if row['OPN']>25:
        t+='O'
    else:
        t+='C'
    data_big_cleaned.at[index, 'B5_TYPE']=t
    
data_big_cleaned
# Out:
#         EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  ...  \
# 0        4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0    1.0  ...
# 1        3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0    5.0  ...
# 2        2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0    5.0  ...
# 3        2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0    4.0  ...
# 4        3.0   3.0   3.0   3.0   5.0   3.0   3.0   5.0   3.0    4.0  ...
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...    ...  ...
# 415057   3.0   1.0   4.0   3.0   2.0   1.0   3.0   4.0   4.0    4.0  ...
# 415058   4.0   2.0   5.0   2.0   4.0   2.0   5.0   4.0   2.0    4.0  ...
# 415059   2.0   2.0   4.0   5.0   4.0   1.0   1.0   1.0   5.0    5.0  ...
# 415060   3.0   1.0   5.0   1.0   4.0   1.0   4.0   2.0   5.0    2.0  ...
# 415061   3.0   4.0   3.0   2.0   4.0   2.0   1.0   2.0   4.0    5.0  ...
#
#         _OPN10   EXT   EST   AGR   CSN   OPN  MAX_SCORE  TYPE      CORR  \
# ...

# %%
print(len(data_big_cleaned['B5_TYPE'].unique()))
print(data_big_cleaned['B5_TYPE'].value_counts())
# Out:
# 32
# ESACO    188860
# ISACO     63694
# ENACO     57451
# INACO     40468
# ESARO     19618
# ENARO     14243
# INARO      8282
# ISARO      6478
# ESTCO      3341
# INTCO      2574
# ISTCO      2164
# ENTCO      1558
# ESACC      1415
# ISACC      1258
# INACC       721
# ENACC       691
# INTRO       537
# ENTRO       335
# ESTRO       298
# ESARC       291
# ISARC       209
# ISTRO       127
# INTCC        85
# ENARC        74
# INARC        73
# ISTRC        51
# ISTCC        35
# ENTCC        35
# INTRC        33
# ESTRC        29
# ESTCC        25
# ENTRC         9
# Name: B5_TYPE, dtype: int64

# %% [markdown]
# # Save new data

# %%
data_big_cleaned.to_csv('data/big_cleaned_results.csv')
